# %% [markdown]
# ### Pandas Homework Assignment II
#
# 23 points
#
# Due by midnight March 4, 2022
#
#
# **To avoid erasing the sample output, please insert a new cell above the sample output**. Write your script inside the new cell and run. Verify your output with the sample output
#
# For lab submission, please rename your file using the following format
#
# `firstname_familyname_Lab4.ipynb`

# %%
# please enter your name and 700# in this cell
Prani Bansal
700724523

# %% [markdown]
# ### Task 0
# + Import numpy as np
# + Import pandas as pd

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1
# Download `stduent_excel.xlsx` from the Blackboard. Load the Spreedsheet into Pandas as a DataFrame. Please skip the first two empty rows when you load the data

# %%
df = pd.read_excel('student_excel.xlsx', 'Sheet1', skiprows = 2)
df
# Out:
#     Unnamed: 0   Name   Course  Score
# 0          NaN   John  CS 1100   85.0
# 1          NaN    NaN  CS 1110   80.0
# 2          NaN    NaN  CS 2300   90.0
# 3          NaN    NaN      NaN    NaN
# 4          NaN  David  CS 1100   85.0
# 5          NaN    NaN  CS 1110    NaN
# 6          NaN    NaN  CS 2300   90.0
# 7          NaN    NaN      NaN    NaN
# 8          NaN  Grace  CS 1100   85.0
# 9          NaN    NaN  CS 1110   80.0
# 10         NaN    NaN  CS 2300   90.0

# %%
# Out:
#     Unnamed: 0   Name   Course  Score
# 0          NaN   John  CS 1100   85.0
# 1          NaN    NaN  CS 1110   80.0
# 2          NaN    NaN  CS 2300   90.0
# 3          NaN    NaN      NaN    NaN
# 4          NaN  David  CS 1100   85.0
# 5          NaN    NaN  CS 1110    NaN
# 6          NaN    NaN  CS 2300   90.0
# 7          NaN    NaN      NaN    NaN
# 8          NaN  Grace  CS 1100   85.0
# 9          NaN    NaN  CS 1110   80.0
# 10         NaN    NaN  CS 2300   90.0

# %% [markdown]
# ### Task 2
# Check and report the number of missing values for each column

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    11
# Name           8
# Course         2
# Score          3
# dtype: int64

# %%
# Out:
# Unnamed: 0    11
# Name           8
# Course         2
# Score          3
# dtype: int64

# %% [markdown]
# ### Task 3
# Select all the rows without missing score

# %%
df[df.Score.notnull()]
# Out:
#     Unnamed: 0   Name   Course  Score
# 0          NaN   John  CS 1100   85.0
# 1          NaN    NaN  CS 1110   80.0
# 2          NaN    NaN  CS 2300   90.0
# 4          NaN  David  CS 1100   85.0
# 6          NaN    NaN  CS 2300   90.0
# 8          NaN  Grace  CS 1100   85.0
# 9          NaN    NaN  CS 1110   80.0
# 10         NaN    NaN  CS 2300   90.0

# %%
# Out:
#     Unnamed: 0   Name   Course  Score
# 0          NaN   John  CS 1100   85.0
# 1          NaN    NaN  CS 1110   80.0
# 2          NaN    NaN  CS 2300   90.0
# 4          NaN  David  CS 1100   85.0
# 6          NaN    NaN  CS 2300   90.0
# 8          NaN  Grace  CS 1100   85.0
# 9          NaN    NaN  CS 1110   80.0
# 10         NaN    NaN  CS 2300   90.0

# %% [markdown]
# ### Task 4
# Delete the coulumn with all missing values

# %%
deleted_column=df.dropna(axis='columns', how='all')

# %%
deleted_column
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 3     NaN      NaN    NaN
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    NaN
# 6     NaN  CS 2300   90.0
# 7     NaN      NaN    NaN
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %%
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 3     NaN      NaN    NaN
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    NaN
# 6     NaN  CS 2300   90.0
# 7     NaN      NaN    NaN
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %% [markdown]
# ### Task 5
# Delete the row with all missing values

# %%
deleted_row = deleted_column.dropna(axis=0, how='all')

# %%
deleted_row
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    NaN
# 6     NaN  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %%
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    NaN
# 6     NaN  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %% [markdown]
# ### Task 6
# Assign the missing score to 0

# %%
deleted_row["Score"].fillna(0.0,inplace=True)
# Out:
# /Users/pranibansal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
deleted_row
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    0.0
# 6     NaN  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %%
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    0.0
# 6     NaN  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %% [markdown]
# ### Task 7
# Fill the missing student names for each score

# %%
deleted_row
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1     NaN  CS 1110   80.0
# 2     NaN  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5     NaN  CS 1110    0.0
# 6     NaN  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9     NaN  CS 1110   80.0
# 10    NaN  CS 2300   90.0

# %%
Filling_Missing_student_name=deleted_row.fillna(method = 'ffill')
Filling_Missing_student_name
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1    John  CS 1110   80.0
# 2    John  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5   David  CS 1110    0.0
# 6   David  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9   Grace  CS 1110   80.0
# 10  Grace  CS 2300   90.0

# %%
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1    John  CS 1110   80.0
# 2    John  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5   David  CS 1110    0.0
# 6   David  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9   Grace  CS 1110   80.0
# 10  Grace  CS 2300   90.0

# %% [markdown]
# ### Task 8
# Save the processed file back into an Excel Spreadsheet and name it `student_excel_clean.xlsx`. Do not save the row indices. The Spreadsheet should look like the one shown below
#
# <div>
# <img src="attachment:f1.png" width="200"/>
# </div>

# %%
Filling_Missing_student_name.to_excel('student_excel_clean.xlsx', index=False)

# %% [markdown]
# ### Task 9
# David took the make up test for CS 1110 and had a score of 70. Use `replace()` to update his grade in the DataFrame

# %%
Filling_Missing_student_name
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1    John  CS 1110   80.0
# 2    John  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5   David  CS 1110    0.0
# 6   David  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9   Grace  CS 1110   80.0
# 10  Grace  CS 2300   90.0

# %%
Updated_David_Score = Filling_Missing_student_name.replace(0.0, 70)
Updated_David_Score
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1    John  CS 1110   80.0
# 2    John  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5   David  CS 1110   70.0
# 6   David  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9   Grace  CS 1110   80.0
# 10  Grace  CS 2300   90.0

# %%
# Out:
#      Name   Course  Score
# 0    John  CS 1100   85.0
# 1    John  CS 1110   80.0
# 2    John  CS 2300   90.0
# 4   David  CS 1100   85.0
# 5   David  CS 1110   70.0
# 6   David  CS 2300   90.0
# 8   Grace  CS 1100   85.0
# 9   Grace  CS 1110   80.0
# 10  Grace  CS 2300   90.0

# %% [markdown]
# ### Task 10
# Pivot the DataFrame in Task 9 from the long format to wide. Use course as the row index and name as the column index

# %%
pivoted_df=Updated_David_Score.pivot(index = 'Course', columns = 'Name', values = 'Score')
pivoted_df
# Out:
# Name     David  Grace  John
# Course
# CS 1100   85.0   85.0  85.0
# CS 1110   70.0   80.0  80.0
# CS 2300   90.0   90.0  90.0

# %%
# Out:
# Name     David  Grace  John
# Course
# CS 1100   85.0   85.0  85.0
# CS 1110   70.0   80.0  80.0
# CS 2300   90.0   90.0  90.0

# %% [markdown]
# ### Task 11
# Ravi's scores for CS 1100, CS 1110 and CS 2300 are 80, 90, and 85, respectively. Create a Series to store his scores

# %%
Ravi = pd.Series({'CS 1100': 80, 'CS 1110': 90,
                  'CS 2300': 85}, name='Ravi')

# %%
Ravi
# Out:
# CS 1100    80
# CS 1110    90
# CS 2300    85
# Name: Ravi, dtype: int64

# %%
# Out:
# CS 1100    80
# CS 1110    90
# CS 2300    85
# Name: Ravi, dtype: int64

# %% [markdown]
# ### Task 12
# Add Ravi's scores as a new column to the DataFrame in Task 10

# %%
pivoted_df['Ravi'] = Ravi.values

# %%
pivoted_df
# Out:
# Name     David  Grace  John  Ravi
# Course
# CS 1100   85.0   85.0  85.0    80
# CS 1110   70.0   80.0  80.0    90
# CS 2300   90.0   90.0  90.0    85

# %%
# Out:
# Name     David  Grace  John  Ravi
# Course
# CS 1100   85.0   85.0  85.0    80
# CS 1110   70.0   80.0  80.0    90
# CS 2300   90.0   90.0  90.0    85

# %% [markdown]
# ### Task 13
# Convert the DataFrame from Task 12 into a multi indexed Series

# %%
pop = pivoted_df.stack()
pop
# Out:
# Course   Name
# CS 1100  David    85.0
#          Grace    85.0
#          John     85.0
#          Ravi     80.0
# CS 1110  David    70.0
#          Grace    80.0
#          John     80.0
#          Ravi     90.0
# CS 2300  David    90.0
#          Grace    90.0
#          John     90.0
#          Ravi     85.0
# dtype: float64

# %%
# Out:
# Course   Name
# CS 1100  David    85.0
#          Grace    85.0
#          John     85.0
#          Ravi     80.0
# CS 1110  David    70.0
#          Grace    80.0
#          John     80.0
#          Ravi     90.0
# CS 2300  David    90.0
#          Grace    90.0
#          John     90.0
#          Ravi     85.0
# dtype: float64

# %% [markdown]
# ### Task 14
# Index the multi indexed Series from Task 13 to obtain the scores for David's three courses

# %%
pop[:,'David']
# Out:
# Course
# CS 1100    85.0
# CS 1110    70.0
# CS 2300    90.0
# dtype: float64

# %%
# Out:
# Course
# CS 1100    85.0
# CS 1110    70.0
# CS 2300    90.0
# dtype: float64

# %% [markdown]
# ### Task 15
# In the multi indexed Series from Task 13, extract the courses and names with a score greater than 80

# %%
pop[pop > 80]
# Out:
# Course   Name
# CS 1100  David    85.0
#          Grace    85.0
#          John     85.0
# CS 1110  Ravi     90.0
# CS 2300  David    90.0
#          Grace    90.0
#          John     90.0
#          Ravi     85.0
# dtype: float64

# %%
# Out:
# Course   Name
# CS 1100  David    85.0
#          Grace    85.0
#          John     85.0
# CS 1110  Ravi     90.0
# CS 2300  David    90.0
#          Grace    90.0
#          John     90.0
#          Ravi     85.0
# dtype: float64

# %% [markdown]
# ### Task 16
# Convert the multi indexed Series from Task 13 into a DataFrame

# %%
convert_df=pop.reset_index().rename(columns = {0: 'Score'})
convert_df
# Out:
#      Course   Name  Score
# 0   CS 1100  David   85.0
# 1   CS 1100  Grace   85.0
# 2   CS 1100   John   85.0
# 3   CS 1100   Ravi   80.0
# 4   CS 1110  David   70.0
# 5   CS 1110  Grace   80.0
# 6   CS 1110   John   80.0
# 7   CS 1110   Ravi   90.0
# 8   CS 2300  David   90.0
# 9   CS 2300  Grace   90.0
# 10  CS 2300   John   90.0
# 11  CS 2300   Ravi   85.0

# %%
# Out:
#      Course   Name  Score
# 0   CS 1100  David   85.0
# 1   CS 1100  Grace   85.0
# 2   CS 1100   John   85.0
# 3   CS 1100   Ravi   80.0
# 4   CS 1110  David   70.0
# 5   CS 1110  Grace   80.0
# 6   CS 1110   John   80.0
# 7   CS 1110   Ravi   90.0
# 8   CS 2300  David   90.0
# 9   CS 2300  Grace   90.0
# 10  CS 2300   John   90.0
# 11  CS 2300   Ravi   85.0

# %% [markdown]
# ### Task 17
#
# Alice, Mark, Bill, Tony, Jason, Ravi, Sandeep, Mounika, John and Curtis took three graduate courses `CS 5000`, `CS 5110` and `CS 5600` in Spring 2022. To simulate the midterm scores they got for the courses, please use a random seed 123 to generate a $10 \times 3$ DataFrame called scores to store the 10 stduents' scores. The scores are random integers in the range of `[30, 100]`

# %%
np.random.seed(123)

# %%
student_random123_scores = np.random.randint(30,100,(10,3))

# %%
student_random123_df = pd.DataFrame(student_random123_scores,
             columns = ['CS5000','CS5110','CS5600'],
             index = ['Alice', 'Mark', 'Bill', 'Tony', 'Jason', 'Ravi', 'Sandeep', 'Mounika', 'John','Curtis'])

# %%
student_random123_df
# Out:
#          CS5000  CS5110  CS5600
# Alice        96      47      87
# Mark         77      62      76
# Bill         55      66      98
# Tony         79      85      97
# Jason        32      69      96
# Ravi         77      91      78
# Sandeep      37      82      57
# Mounika      64      70      33
# John         99      94      64
# Curtis       88      40      52

# %%
# Out:
#          CS 5000  CS 5110  CS 5600
# Alice         96       47       87
# Mark          77       62       76
# Bill          55       66       98
# Tony          79       85       97
# Jason         32       69       96
# Ravi          77       91       78
# Sandeep       37       82       57
# Mounika       64       70       33
# John          99       94       64
# Curtis        88       40       52

# %% [markdown]
# ### Task 18
#
# Repeat Task 19 to generate the final scores for those stduents. Please use a random seed of 456 to generate the data

# %%
np.random.seed(456)
student_random456_scores = np.random.randint(30,100,(10,3))

# %%
student_random456_df=pd.DataFrame(student_random456_scores,
             columns = ['CS5000','CS5110','CS5600'],
             index = ['Alice', 'Mark', 'Bill', 'Tony', 'Jason', 'Ravi', 'Sandeep', 'Mounika', 'John','Curtis'])
student_random456_df
# Out:
#          CS5000  CS5110  CS5600
# Alice        57      73      72
# Mark         58      90      75
# Bill         67      69      41
# Tony         99      64      96
# Jason        34      38      92
# Ravi         46      71      40
# Sandeep      74      65      78
# Mounika      81      83      52
# John         65      86      52
# Curtis       36      74      74

# %%
# Out:
#          CS 5000  CS 5110  CS 5600
# Alice         57       73       72
# Mark          58       90       75
# Bill          67       69       41
# Tony          99       64       96
# Jason         34       38       92
# Ravi          46       71       40
# Sandeep       74       65       78
# Mounika       81       83       52
# John          65       86       52
# Curtis        36       74       74

# %% [markdown]
# ### Task 19
# Concatenate the two DataFrames from Task 19 and Task 20 into a new DataFrame with multi index

# %%
concatenated_df = {'Midterm' : student_random123_df, 'Final' : student_random456_df}
#new_concatenated_df=pd.concat(concatenated_df.values(), axis=0, keys=concatenated_df.keys())
concatenated_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/56/plm6ts814hj714s5vcdw5h040000gn/T/ipykernel_3052/297648517.py in <module>
# ----> 1 concatenated_df = {'Midterm' : student_random123_df, 'Final' : student_random456_df}
#       2 #new_concatenated_df=pd.concat(concatenated_df.values(), axis=0, keys=concatenated_df.keys())
#       3 concatenated_df
#
# NameError: name 'student_random123_df' is not defined

# %%
# Out:
#                  CS 5000  CS 5110  CS 5600
# Midterm Alice         96       47       87
#         Mark          77       62       76
#         Bill          55       66       98
#         Tony          79       85       97
#         Jason         32       69       96
#         Ravi          77       91       78
#         Sandeep       37       82       57
#         Mounika       64       70       33
#         John          99       94       64
#         Curtis        88       40       52
# Final   Alice         57       73       72
#         Mark          58       90       75
#         Bill          67       69       41
#         Tony          99       64       96
#         Jason         34       38       92
#         Ravi          46       71       40
#         Sandeep       74       65       78
#         Mounika       81       83       52
#         John          65       86       52
#         Curtis        36       74       74

# %% [markdown]
# ### Task 20
# Name the multi index with `Term` and `Name`, respectively

# %%
renaming_multiindex = new_concatenated_df.rename_axis(['Term','Name'])
renaming_multiindex
# Out:
#                  CS5000  CS5110  CS5600
# Term    Name
# Midterm Alice        96      47      87
#         Mark         77      62      76
#         Bill         55      66      98
#         Tony         79      85      97
#         Jason        32      69      96
#         Ravi         77      91      78
#         Sandeep      37      82      57
#         Mounika      64      70      33
#         John         99      94      64
#         Curtis       88      40      52
# Final   Alice        57      73      72
#         Mark         58      90      75
#         Bill         67      69      41
#         Tony         99      64      96
#         Jason        34      38      92
#         Ravi         46      71      40
#         Sandeep      74      65      78
#         Mounika      81      83      52
#         John         65      86      52
#         Curtis       36      74      74

# %% [markdown]
# ### Task 21
# Swap the level of the multi index

# %%
swapping_level=renaming_multiindex.groupby(['Name','Term'])
swapping_level.first()
# Out:
#                  CS5000  CS5110  CS5600
# Name    Term
# Alice   Midterm      96      47      87
#         Final        57      73      72
# Mark    Midterm      77      62      76
#         Final        58      90      75
# Bill    Midterm      55      66      98
#         Final        67      69      41
# Tony    Midterm      79      85      97
#         Final        99      64      96
# Jason   Midterm      32      69      96
#         Final        34      38      92
# Ravi    Midterm      77      91      78
#         Final        46      71      40
# Sandeep Midterm      37      82      57
#         Final        74      65      78
# Mounika Midterm      64      70      33
#         Final        81      83      52
# John    Midterm      99      94      64
#         Final        65      86      52
# Curtis  Midterm      88      40      52
#         Final        36      74      74

# %%
# Out:
#                  CS 5000  CS 5110  CS 5600
# Name    Term
# Alice   Midterm       96       47       87
#         Final         57       73       72
# Mark    Midterm       77       62       76
#         Final         58       90       75
# Bill    Midterm       55       66       98
#         Final         67       69       41
# Tony    Midterm       79       85       97
#         Final         99       64       96
# Jason   Midterm       32       69       96
#         Final         34       38       92
# Ravi    Midterm       77       91       78
#         Final         46       71       40
# Sandeep Midterm       37       82       57
#         Final         74       65       78
# Mounika Midterm       64       70       33
#         Final         81       83       52
# John    Midterm       99       94       64
#         Final         65       86       52
# Curtis  Midterm       88       40       52
#         Final         36       74       74

# %% [markdown]
# ### Task 22
# Find the average scores for midterm and final for all three courses

# %%
average_scores = renaming_multiindex.mean(level = 'Term')
average_scores
# Out:
# /var/folders/56/plm6ts814hj714s5vcdw5h040000gn/T/ipykernel_2803/1069232086.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
#   average_scores = renaming_multiindex.mean(level = 'Term')
#          CS5000  CS5110  CS5600
# Term
# Midterm    70.4    70.6    73.8
# Final      61.7    71.3    67.2

# %%
# Out:
#          CS 5000  CS 5110  CS 5600
# Term
# Midterm     70.4     70.6     73.8
# Final       61.7     71.3     67.2

# %% [markdown]
# ### Task 23
# From the DataFrame in Task 21, extract all students' midterm scores

# %%
students_midterm_scores=swapping_level.first()
students_midterm_scores[students_midterm_scores.index.get_level_values(level=1)=="Midterm"]
# Out:
#                  CS5000  CS5110  CS5600
# Name    Term
# Alice   Midterm      96      47      87
# Mark    Midterm      77      62      76
# Bill    Midterm      55      66      98
# Tony    Midterm      79      85      97
# Jason   Midterm      32      69      96
# Ravi    Midterm      77      91      78
# Sandeep Midterm      37      82      57
# Mounika Midterm      64      70      33
# John    Midterm      99      94      64
# Curtis  Midterm      88      40      52

# %%
# Out:
#                  CS 5000  CS 5110  CS 5600
# Name    Term
# Alice   Midterm       96       47       87
# Mark    Midterm       77       62       76
# Bill    Midterm       55       66       98
# Tony    Midterm       79       85       97
# Jason   Midterm       32       69       96
# Ravi    Midterm       77       91       78
# Sandeep Midterm       37       82       57
# Mounika Midterm       64       70       33
# John    Midterm       99       94       64
# Curtis  Midterm       88       40       52
